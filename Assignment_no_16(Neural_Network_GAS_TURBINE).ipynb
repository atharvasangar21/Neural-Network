# %% [markdown]
# # Problem statement: predicting turbine energy yield (TEY) using ambient variables as features.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import warnings
warnings.filterwarnings('ignore')

# %%
gas_turbine = pd.read_csv('/content/gas_turbines.csv')
gas_turbine
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 0      3.1547  82.722
# 1      3.2363  82.776
# 2      3.2012  82.468
# 3      3.1923  82.670
# 4      3.2484  82.311
# ...       ...     ...
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498
#
# [15039 rows x 11 columns]

# %% [markdown]
# ## About DataSet
#
# The Dataset contains 36733 instances of 11 sensor measures aggregated over one hour (by means of average or sum) from a gas turbine.
#
# The Dataset includes gas turbine parameters (such as Turbine Inlet Temperature and Compressor Discharge pressure) in addition to the ambient variables.
#
# The explanations of sensor measurements and their brief statistics are given below.
#
# Variable (Abbr.) Unit Min Max Mean
#
# Ambient temperature (AT) C â€“6.23 37.10 17.71
#
# Ambient pressure (AP) mbar 985.85 1036.56 1013.07
#
# Ambient humidity (AH) (%) 24.08 100.20 77.87
#
# Air filter difference pressure (AFDP) mbar 2.09 7.61 3.93
#
# Gas turbine exhaust pressure (GTEP) mbar 17.70 40.72 25.56
#
# Turbine inlet temperature (TIT) C 1000.85 1100.89 1081.43
#
# Turbine after temperature (TAT) C 511.04 550.61 546.16
#
# Compressor discharge pressure (CDP) mbar 9.85 15.16 12.06
#
# Turbine energy yield (TEY) MWH 100.02 179.50 133.51
#
# Carbon monoxide (CO) mg/m3 0.00 44.10 2.37
#
# Nitrogen oxides (NOx) mg/m3 25.90 119.91 65.29

# %% [markdown]
# ## EDA

# %%
# Checking Null Values and DType 

gas_turbine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %% [markdown]
# **No Null Values in Data**

# %%
# Checking Duplicate values

gas_turbine[gas_turbine.duplicated()]
# Out:
# Empty DataFrame
# Columns: [AT, AP, AH, AFDP, GTEP, TIT, TAT, TEY, CDP, CO, NOX]
# Index: []

# %% [markdown]
# **No Duplicates in Data**

# %%
# Describe

gas_turbine.describe()
# Out:
#                  AT           AP            AH          AFDP          GTEP  \
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           TEY           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean    1083.798770    545.396183    134.188464     12.102353      1.972499
# std       16.527806      7.866803     15.829717      1.103196      2.222206
# min     1000.800000    512.450000    100.170000      9.904400      0.000388
# 25%     1079.600000    542.170000    127.985000     11.622000      0.858055
# 50%     1088.700000    549.890000    133.780000     12.025000      1.390200
# 75%     1096.000000    550.060000    140.895000     12.578000      2.160400
# max     1100.800000    550.610000    174.610000     15.081000     44.103000
#
#                 NOX
# count  15039.000000
# mean      68.190934
# std       10.470586
# min       27.765000
# 25%       61.303500
# 50%       66.601000
# 75%       73.935500
# max      119.890000

# %%
# Correlate

gas_turbine.corr()
# Out:
#             AT        AP        AH      AFDP      GTEP       TIT       TAT  \
# AT    1.000000 -0.412953 -0.549432 -0.099333 -0.049103  0.093067  0.338569
# AP   -0.412953  1.000000  0.042573  0.040318  0.078575  0.029650 -0.223479
# AH   -0.549432  0.042573  1.000000 -0.119249 -0.202784 -0.247781  0.010859
# AFDP -0.099333  0.040318 -0.119249  1.000000  0.744251  0.627254 -0.571541
# GTEP -0.049103  0.078575 -0.202784  0.744251  1.000000  0.874526 -0.756884
# TIT   0.093067  0.029650 -0.247781  0.627254  0.874526  1.000000 -0.357320
# TAT   0.338569 -0.223479  0.010859 -0.571541 -0.756884 -0.357320  1.000000
# TEY  -0.207495  0.146939 -0.110272  0.717995  0.977042  0.891587 -0.720356
# CDP  -0.100705  0.131198 -0.182010  0.727152  0.993784  0.887238 -0.744740
# CO   -0.088588  0.041614  0.165505 -0.334207 -0.508259 -0.688272  0.063404
# NOX  -0.600006  0.256744  0.143061 -0.037299 -0.208496 -0.231636  0.009888
#
#            TEY       CDP        CO       NOX
# AT   -0.207495 -0.100705 -0.088588 -0.600006
# AP    0.146939  0.131198  0.041614  0.256744
# AH   -0.110272 -0.182010  0.165505  0.143061
# AFDP  0.717995  0.727152 -0.334207 -0.037299
# GTEP  0.977042  0.993784 -0.508259 -0.208496
# TIT   0.891587  0.887238 -0.688272 -0.231636
# TAT  -0.720356 -0.744740  0.063404  0.009888
# TEY   1.000000  0.988473 -0.541751 -0.102631
# CDP   0.988473  1.000000 -0.520783 -0.169103
# CO   -0.541751 -0.520783  1.000000  0.316743
# NOX  -0.102631 -0.169103  0.316743  1.000000

# %% [markdown]
# ## Visualization

# %%
# create histogram for each variabel to check normality.
gas_turbine.hist(bins = 30, figsize= (10, 10) )
plt.show()

# %% [markdown]
# The dataset is clean and has no null values. From the "describe" function it can be seen that almost all variable holds a low SD, so the data is more concentrated to the mean. Not all the features are normally distributed, So I'll be going to normalize the data before training a model.

# %%
# Check the outliers 

gas_turbine.boxplot(figsize = (10, 10), widths = 1)

# %% [markdown]
# The boxplot shows that more input variables are outliers, So I'll be using mean absolute error (MAE) to evaluate the model in modeling.  As MAE is not sensitive to the outliers

# %%
## Correlating data with HeatMap

cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]
corr = gas_turbine.corr()
corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style type="text/css">
# #T_ac633_ th {
#   font-size: 7pt;
# }
# #T_ac633_ td {
#   padding: 0em 0em;
# }
# #T_ac633_ th:hover {
#   font-size: 12pt;
# }
# #T_ac633_ tr:hover td:hover {
#   max-width: 200px;
#   font-size: 12pt;
# }
# #T_ac633_row0_col0, #T_ac633_row1_col1, #T_ac633_row2_col2, #T_ac633_row3_col3, #T_ac633_row4_col4, #T_ac633_row4_col8, #T_ac633_row5_col5, #T_ac633_row6_col6, #T_ac633_row7_col7, #T_ac633_row8_col4, #T_ac633_row8_col8, #T_ac633_row9_col9, #T_ac633_row10_col10 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row0_col1 {
#   background-color: #dd657d;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row0_col2 {
#   background-color: #d94764;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row0_col3, #T_ac633_row1_col5, #T_ac633_row4_col2 {
#   background-color: #e8aeba;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row0_col4 {
#   background-color: #eab9c3;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row0_col5, #T_ac633_row9_col1 {
#   background-color: #efd9dd;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row0_col6 {
#   background-color: #d3dce9;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row0_col7, #T_ac633_row10_col4 {
#   background-color: #e494a4;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row0_col8, #T_ac633_row4_col10, #T_ac633_row10_col7 {
#   background-color: #e8adb8;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row0_col9 {
#   background-color: #e9afbb;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row0_col10, #T_ac633_row1_col0, #T_ac633_row2_col0, #T_ac633_row3_col6, #T_ac633_row4_col6, #T_ac633_row5_col9, #T_ac633_row6_col4, #T_ac633_row7_col6, #T_ac633_row8_col6, #T_ac633_row9_col5, #T_ac633_row10_col0 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row1_col2, #T_ac633_row1_col3, #T_ac633_row1_col9, #T_ac633_row8_col2 {
#   background-color: #e9b1bc;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row1_col4 {
#   background-color: #eabbc4;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row1_col6 {
#   background-color: #de6c83;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row1_col7 {
#   background-color: #edccd2;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row1_col8 {
#   background-color: #ecc8cf;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row1_col10, #T_ac633_row4_col1 {
#   background-color: #f1e8ea;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row2_col1, #T_ac633_row10_col6 {
#   background-color: #ecc6ce;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row2_col3 {
#   background-color: #e6a1af;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row2_col4 {
#   background-color: #e38d9e;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row2_col5 {
#   background-color: #e28194;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row2_col6 {
#   background-color: #ebbfc8;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row2_col7 {
#   background-color: #e7a3b0;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row2_col8 {
#   background-color: #e491a1;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row2_col9, #T_ac633_row5_col0, #T_ac633_row10_col2 {
#   background-color: #f0e4e6;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row2_col10 {
#   background-color: #f0dee2;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row3_col0, #T_ac633_row7_col0 {
#   background-color: #e7a8b5;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row3_col1 {
#   background-color: #ecc9d0;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row3_col2 {
#   background-color: #e7a4b1;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row3_col4, #T_ac633_row7_col3 {
#   background-color: #7b9fcd;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row3_col5 {
#   background-color: #95b1d5;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row3_col7 {
#   background-color: #81a3ce;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row3_col8 {
#   background-color: #7fa2ce;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row3_col9 {
#   background-color: #df7288;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row3_col10 {
#   background-color: #eab8c2;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row4_col0 {
#   background-color: #edcfd5;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row4_col3 {
#   background-color: #769ccb;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row4_col5 {
#   background-color: #5c8ac2;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row4_col7, #T_ac633_row7_col4 {
#   background-color: #487cbc;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row4_col9 {
#   background-color: #df6f85;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row5_col1 {
#   background-color: #eed6db;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row5_col2 {
#   background-color: #e59aa9;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row5_col3 {
#   background-color: #90aed3;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row5_col4 {
#   background-color: #5e8bc3;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row5_col6 {
#   background-color: #e28396;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row5_col7, #T_ac633_row7_col5, #T_ac633_row8_col5 {
#   background-color: #5a88c2;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row5_col8 {
#   background-color: #5b89c2;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row5_col10 {
#   background-color: #e69ead;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row6_col0 {
#   background-color: #c7d4e5;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row6_col1 {
#   background-color: #e8aab6;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row6_col2, #T_ac633_row6_col10 {
#   background-color: #efdade;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row6_col3, #T_ac633_row9_col4 {
#   background-color: #dd627b;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row6_col5, #T_ac633_row10_col5 {
#   background-color: #e48e9f;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row6_col7 {
#   background-color: #d84361;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row6_col8 {
#   background-color: #d73d5c;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row6_col9 {
#   background-color: #f1e5e7;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row7_col1, #T_ac633_row9_col2 {
#   background-color: #eff0f2;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row7_col2, #T_ac633_row9_col0, #T_ac633_row10_col3 {
#   background-color: #eabcc5;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row7_col8, #T_ac633_row8_col7 {
#   background-color: #457abb;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row7_col9 {
#   background-color: #dd6179;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row7_col10 {
#   background-color: #ebbec6;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row8_col0 {
#   background-color: #ebc2ca;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row8_col1 {
#   background-color: #f1f1f2;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_ac633_row8_col3 {
#   backgro

# %% [markdown]
#  bold textThe heatmap above shows the correlation between features and output variables(CO and NOx). It is easy to see that some features are negatively correlated with each other. For example, the correlation between TIT and CO is -0.71, and it means that when the Turbine Inlet Temperature (TIT) decreases, the gas-turbine engine will produce more CO because a low TIT reduces the efficiency of the gas-turbine engine.

# %% [markdown]
# ## Model Building

# %%
# selecting NOX as target variabel

 # drop the target variable CO
nox_df = gas_turbine.copy()
nox_df = nox_df.drop("CO", axis = 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Normalizer

# %%
X = nox_df.iloc[:, 0:-1]
y = nox_df["NOX"]

# %%
# normalize the X and y.

X = nox_df = Normalizer().fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,  test_size = 0.2,random_state= 0, shuffle = True)

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression ()
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error


y_pred = linear_model.predict(X_test)
mae_linear = mean_absolute_error(y_test, y_pred)
print("MAE on testset is:", round(mae_linear, 3))
# Out:
# MAE on testset is: 4.983

# %% [markdown]
# ### Random Forest

# %%
from numpy import mean
from numpy import std
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor( )

# %%
# evaluate the model

cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')

# %%
# report performance
print('MAE on cross validation set : %.3f (%.3f)' % (abs(mean(n_scores)), std(n_scores)))
# Out:
# MAE on cross validation set : 2.230 (0.082)

# %%
# fit the model 
model = RandomForestRegressor(random_state =0)
model = model.fit(X_train, y_train)

# %% [markdown]
# ###  MAE on test set again

# %%
from sklearn.metrics import mean_absolute_error
from sklearn import metrics 

y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)

print("MAE on test set:", round (mae, 3))
# Out:
# MAE on test set: 2.37

# %% [markdown]
# **Conclusion**
# Looks like the Random forest works well on this dataset and is also better than the simple linear regression model. I just applied the random forest model with default parameters, and I'm amazed that a simple random forest model can fit the data so well.
